# %%
# %matplotlib
import numpy as np
import pandas as pd
import seaborn as sns
sns.set()
# Out:
# Using matplotlib backend: TkAgg

# %%
iris = sns.load_dataset("iris")
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
type(iris)
# Out:
# pandas.core.frame.DataFrame

# %%
sns.pairplot(iris, hue='species', size=2.5)

# %%
# !curl -0 https://raw.githubusercontent.com/jakevdp/marathon-data/master/marathon-data.csv
# Out:
# age,gender,split,final
# 33,M,01:05:38,02:08:51
# 32,M,01:06:26,02:09:28
# 31,M,01:06:49,02:10:42
# 38,M,01:06:16,02:13:45
# 31,M,01:06:32,02:13:59
# 31,M,01:06:13,02:14:11
# 27,M,01:06:40,02:14:28
# 31,M,01:06:31,02:15:16
# 30,M,01:05:39,02:15:57
# 30,M,01:05:40,02:16:39
# 26,M,01:08:10,02:18:18
# 29,M,01:05:54,02:18:52
# 28,M,01:08:59,02:19:36
# 24,M,01:09:16,02:19:45
# 37,M,01:05:21,02:19:47
# 25,M,01:09:52,02:20:17
# 22,M,01:09:53,02:20:57
# 30,M,01:05:40,02:21:17
# 26,M,01:10:11,02:21:24
# 36,M,01:10:35,02:21:55
# 28,M,01:11:59,02:22:14
# 31,M,01:05:54,02:22:20
# 41,M,01:09:14,02:22:27
# 24,M,01:11:18,02:22:55
# 26,M,01:10:17,02:22:56
# 36,M,01:06:39,02:23:31
# 28,M,01:10:32,02:23:39
# 29,M,01:12:25,02:23:48
# 34,W,01:12:35,02:24:13
# 31,M,01:14:07,02:25:19
# 39,W,01:13:13,02:25:37
# 29,M,01:09:59,02:25:38
# 29,W,01:13:09,02:25:50
# 31,M,01:13:24,02:25:56
# 30,M,01:11:51,02:26:15
# 30,M,01:08:34,02:26:36
# 34,M,01:06:20,02:27:22
# 27,M,01:12:23,02:27:24
# 23,M,01:13:42,02:27:32
# ...

# %%
marathon = pd.read_csv("marathon-data.csv")
marathon.head()
# Out:
#    age gender     split     final
# 0   33      M  01:05:38  02:08:51
# 1   32      M  01:06:26  02:09:28
# 2   31      M  01:06:49  02:10:42
# 3   38      M  01:06:16  02:13:45
# 4   31      M  01:06:32  02:13:59

# %%
import matplotlib.pyplot as plt
planets = sns.load_dataset("planets")

f, ax = plt.subplots(figsize=(7, 6))
ax.set_xscale("log")

sns.boxplot(x="distance", y="method", data=planets, whis=np.inf, palette="vlag")
sns.swarmplot(x="distance", y="method", data=planets, size=2, color=".3", linewidth=0)
ax.xaxis.grid(True)
ax.set(ylabel="")
sns.despine(trim=True, left=True)
# Out:
# /usr/local/lib/python3.5/dist-packages/matplotlib/cbook.py:2052: RuntimeWarning: invalid value encountered in double_scalars
#   loval = q1 - whis * stats['iqr']
# /usr/local/lib/python3.5/dist-packages/matplotlib/cbook.py:2053: RuntimeWarning: invalid value encountered in double_scalars
#   hival = q3 + whis * stats['iqr']
# /usr/local/lib/python3.5/dist-packages/matplotlib/cbook.py:2066: RuntimeWarning: invalid value encountered in less_equal
#   wiskhi = np.compress(x <= hival, x)
# /usr/local/lib/python3.5/dist-packages/matplotlib/cbook.py:2073: RuntimeWarning: invalid value encountered in greater_equal
#   wisklo = np.compress(x >= loval, x)
