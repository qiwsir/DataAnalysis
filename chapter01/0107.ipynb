# %%
import numpy as np
import math
f1 = np.array([10*math.cos(math.pi/6), 10*math.sin(math.pi/6)])
f2 = np.array([0, 12])
f = f1 + f2
f
# Out:
# array([  8.66025404,  17.        ])

# %%
np.sqrt(np.sum(f**2))
# Out:
# 19.078784028338912

# %%
np.linalg.norm(f)
# Out:
# 19.078784028338912

# %%
f = np.array([6*math.cos(math.pi/6), 6*math.sin(math.pi/6)])
s = np.array([10, 0])
np.dot(f, s)
# Out:
# 51.96152422706632

# %%
c = np.array([[1, 2], [3, 4]])
d = np.array([[5, 6], [7, 8]])
np.dot(c, d)
# Out:
# array([[19, 22],
#        [43, 50]])

# %%
np.inner(f, s)
# Out:
# 51.96152422706632

# %%
 np.inner(c, d)
# Out:
# array([[17, 23],
#        [39, 53]])

# %%
ab = np.array([4, 1])
ac = np.array([1, 2])
s = np.cross(ab, ac) / 2
s
# Out:
# 3.5

# %%
v = np.array([1,2,3])
b = np.array([9, 8, 7])
np.cross(v, b)
# Out:
# array([-10,  20, -10])

# %%
np.cross(c, d)
# Out:
# array([-4, -4])

# %%
v
# Out:
# array([1, 2, 3])

# %%
b
# Out:
# array([9, 8, 7])

# %%
np.outer(v, b)
# Out:
# array([[ 9,  8,  7],
#        [18, 16, 14],
#        [27, 24, 21]])

# %%
a = np.arange(6).reshape(2, 3)
b = np.arange(9).reshape(3, 3)
np.dot(a, b)
# Out:
# array([[15, 18, 21],
#        [42, 54, 66]])

# %%
np.tensordot(a, b, axes=([1], [0]))
# Out:
# array([[15, 18, 21],
#        [42, 54, 66]])

# %%
a = np.random.randint(2, size=(2, 6, 5))
b = np.random.randint(2, size=(3, 2, 4))

# %%
np.dot(a, b)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-17-579c274cec9b> in <module>()
# ----> 1 np.dot(a, b)
#
# ValueError: shapes (2,6,5) and (3,2,4) not aligned: 5 (dim 2) != 2 (dim 1)

# %%
np.tensordot(a, b, axes=([0], [1])).shape
# Out:
# (6, 5, 3, 4)

# %%
c = np.random.randint(2, size=(2,3,5))
d = np.random.randint(2, size=(3,2,4))
np.tensordot(c, d, axes=((0, 1), (1, 0)))
# Out:
# array([[4, 4, 1, 2],
#        [1, 1, 0, 1],
#        [1, 1, 1, 0],
#        [1, 2, 0, 1],
#        [4, 5, 1, 3]])

# %%
np.tensordot(c, d, axes=((0, 1), (1, 0))).shape
# Out:
# (5, 4)
